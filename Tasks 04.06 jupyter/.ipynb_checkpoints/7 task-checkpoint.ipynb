# %%
#7) Create a box plot to visualize the distribution of a variable across different categories.

import pandas as pd
data = pd.read_excel(r'C:\Users\pauli\Desktop\PhytonCourse\healthy_year.xlsx')
data
# Out:
#                                         GEO (Labels)   Gender  2011  2012
# 0                                            Belgium    Males  63.4  64.2  \
# 1                                           Bulgaria    Males  62.1  62.1
# 2                                            Czechia    Males  62.2  62.3
# 3                                            Denmark    Males  63.7  61.2
# 4   Germany (until 1990 former territory of the FRG)    Males  57.8  57.3
# ..                                               ...      ...   ...   ...
# 57                                            Sweden  Females  64.6  64.8
# 58                                           Iceland  Females  67.7  68.0
# 59                                            Norway  Females  76.1  70.4
# 60                                       Switzerland  Females  64.7  67.6
# 61                                    United Kingdom  Females  65.2  64.5
#
#     2013  2014  2015  2016  2017  2018  2019  2020
# ...

# %%
import matplotlib.pyplot as pl
years = ['2017','2018','2019','2020']
y_2017 = data['2017']
y_2018 = data['2018']
y_2019 = data['2019']
y_2020 = data['2020']

data1 = [y_2017, y_2018, y_2019, y_2020]

pl.boxplot(data1, labels=years)

pl.title("Average of healthy years by females and males")
pl.xlabel("Year")
pl.ylabel("Av_years")

pl.show()
