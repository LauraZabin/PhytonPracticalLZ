# %%
#5) Create a line chart using Matplotlib to visualize the trend of a variable over time.
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel(r'C:\Users\pauli\Desktop\PhytonCourse\climatic_anual_avg.xlsx')
data
# Out:
#     Year  Vilnius  Kaunas  Palanga
# 0   1998      6.6     9.5      9.1
# 1   1999      7.6     9.5      9.1
# 2   2000      7.8     9.5      9.1
# 3   2001      6.7     8.3      8.1
# 4   2003      6.4     8.3      8.1
# 5   2004      6.3     7.8      7.8
# 6   2006      7.0     8.5      8.5
# 7   2007      7.6     8.6      8.8
# 8   2008      7.8     8.8      9.0
# 9   2009      6.8     7.3      8.0
# 10  2010      6.3     6.7      6.7
# 11  2011      7.3     8.1      8.5
# 12  2012      6.5     7.0      7.5
# 13  2013      7.3     7.8      8.3
# 14  2014      7.7     8.0      8.5
# 15  2015      8.3     8.6      8.8
# 16  2016      7.3     7.8      8.3
# 17  2017      7.3     7.9      8.1
# 18  2018      8.1     8.6      8.7
# 19  2019      8.5     9.1      9.4
# 20  2020      8.7     9.4      9.8
# 21  2021      7.1     7.7      7.8
# 22  2022      7.6     8.1      8.8

# %%
plt.plot(data.Year, data.Vilnius)
plt.title("Average of temp by years")
plt.xlabel("Year")
plt.ylabel("AVG of temp")
plt.show()
