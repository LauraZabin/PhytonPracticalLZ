# %%
# 6) Use Pandas to merge two datasets together based on a common key
# (try this function - merge(table1, table2, on='Column1', how='inner').

import pandas as pd
data1 = pd.read_excel(r'C:\Users\pauli\Desktop\PhytonCourse\Tasks 04.06 jupyter\Females.xlsx')
data1
# Out:
#                                         GEO (Labels)   Gender  2020_females
# 0                                            Belgium  Females          64.0
# 1                                           Bulgaria  Females          67.8
# 2                                            Czechia  Females          62.5
# 3                                            Denmark  Females          57.7
# 4   Germany (until 1990 former territory of the FRG)  Females          66.8
# 5                                            Estonia  Females          59.6
# 6                                            Ireland  Females          67.1
# 7                                             Greece  Females          66.8
# 8                                              Spain  Females          66.3
# 9                                             France  Females          65.3
# 10                                           Croatia  Females          59.6
# ...

# %%
data2 = pd.read_excel(r'C:\Users\pauli\Desktop\PhytonCourse\Tasks 04.06 jupyter\Males.xlsx')
data2
# Out:
#                                         GEO (Labels) Gender1  2020_males
# 0                                            Belgium   Males        63.6
# 1                                           Bulgaria   Males        63.6
# 2                                            Czechia   Males        60.9
# 3                                            Denmark   Males        58.1
# 4   Germany (until 1990 former territory of the FRG)   Males        64.7
# 5                                            Estonia   Males        55.5
# 6                                            Ireland   Males        65.3
# 7                                             Greece   Males        65.0
# 8                                              Spain   Males        66.3
# 9                                             France   Males        63.9
# 10                                           Croatia   Males        57.5
# 11                                             Italy   Males        67.2
# ...

# %%
merged_data = data1.merge(data2, on='GEO (Labels)', how='inner')
merged_data
# Out:
#                                         GEO (Labels)   Gender  2020_females
# 0                                            Belgium  Females          64.0  \
# 1                                           Bulgaria  Females          67.8
# 2                                            Czechia  Females          62.5
# 3                                            Denmark  Females          57.7
# 4   Germany (until 1990 former territory of the FRG)  Females          66.8
# 5                                            Estonia  Females          59.6
# 6                                            Ireland  Females          67.1
# 7                                             Greece  Females          66.8
# 8                                              Spain  Females          66.3
# 9                                             France  Females          65.3
# 10                                           Croatia  Females          59.6
# ...
